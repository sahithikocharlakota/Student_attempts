# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('/content/drive/MyDrive/Student-1 (1).xlsx')

# %%
df.shape
# Out:
# (170, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170 entries, 0 to 169
# Data columns (total 12 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   SL                                                          170 non-null    int64
#  1   Age                                                         170 non-null    int64
#  2   Gender                                                      170 non-null    object
#  3   Class X percentage/CGPA                                     170 non-null    object
#  4   Class XII percentage/CGPA                                   170 non-null    float64
#  5   Bachelors' Degree                                           170 non-null    object
#  6   Bachelors' Marks/CGPA                                       170 non-null    object
# ...

# %%
df.head()
# Out:
#    SL  Age  Gender Class X percentage/CGPA  Class XII percentage/CGPA  \
# 0   1   23    Male                      92                      93.00
# 1   2   23  Female                     9.4                      78.80
# 2   3   24  Female                     8.8                      86.20
# 3   4   24    Male                    89.4                      77.20
# 4   5   22  Female                9.4 cgpa                       0.89
#
#                        Bachelors' Degree Bachelors' Marks/CGPA  \
# 0                                 B.TECH                  8.66
# 1                                   77.6              821/1000
# 2  B.Tech in Computer Science Enineering                   8.8
# 3                                 B.Tech                   7.2
# 4                          Bcom. Honours             7.34 cgpa
#
#    Work Experience (in completed months) (write 0 if fresher)  Term 1 CGPA  \
# 0                                                  0                  3.00
# ...

# %%
df = df.drop('SL',axis=1)

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df['Bachelors\' Degree'].unique()
# Out:
# array(['B.TECH', 77.6, 'B.Tech in Computer Science Enineering', 'B.Tech',
#        'Bcom. Honours', 'B.Com', 'B.tech Food Technology ', 'BCom Hons.',
#        'B.Com (Hons.)', 'Btech Civil engineering',
#        'Bachelor of Commerce (Honours)',
#        'Bachelor of Business Administration ',
#        'BE (Electronics and Telecommunication)', 'B-Tech Civil',
#        'B.Tech ', '9.15/10', 'B.Tech Mechanical Engineering', 'BE',
#        'Civil Engineering', 'Bachelors in Management Studies', 'B.COM',
#        'BA.LLB(Hons.) ', 'BBA', 'Bachelor of Engineering', 'bcom', 'BCA',
#        'B.com', 'B.com (Hons.)', 'B.tech', 'Bcom',
#        'Electrical and Electronics Engineering ',
#        'B.Tech in Computer Science', 'B.com (Hons)', 'B.Com Hons.',
#        'b.com(hons)', 'Bachleor in Arts of Mass Communication',
#        'B.Tech. Mechanical Engineering', 'B.E. Computer Science',
#        'Bsc Physics Hons', 64,
#        'B.Tech - Electronics and Communication Engineering',
# ...

# %%
df['Bachelors\' Degree'] = df['Bachelors\' Degree'].str.lower()

# %%
df['Bachelors\' Degree'].isnull().sum()
# Out:
# 4

# %%
df['Bachelors\' Degree']=df['Bachelors\' Degree'].fillna(method='pad')

# %%
df['Bachelors\' Degree'].isnull().sum()
# Out:
# 0

# %%
df['Bachelors\' Degree'].nunique()
# Out:
# 100

# %%
df['Bachelors\' Degree'].unique()
# Out:
# array(['b.tech', 'b.tech in computer science enineering', 'bcom. honours',
#        'b.com', 'b.tech food technology ', 'bcom hons.', 'b.com (hons.)',
#        'btech civil engineering', 'bachelor of commerce (honours)',
#        'bachelor of business administration ',
#        'be (electronics and telecommunication)', 'b-tech civil',
#        'b.tech ', '9.15/10', 'b.tech mechanical engineering', 'be',
#        'civil engineering', 'bachelors in management studies',
#        'ba.llb(hons.) ', 'bba', 'bachelor of engineering', 'bcom', 'bca',
#        'electrical and electronics engineering ',
#        'b.tech in computer science', 'b.com (hons)', 'b.com hons.',
#        'b.com(hons)', 'bachleor in arts of mass communication',
#        'b.tech. mechanical engineering', 'b.e. computer science',
#        'bsc physics hons',
#        'b.tech - electronics and communication engineering',
#        'b.a (hons) economics', 'bcom (hons)', 'be mechanical',
# ...

# %%
for i in df['Bachelors\' Degree'].head():
  print(i)
# Out:
# b.tech
# b.tech
# b.tech in computer science enineering
# b.tech
# bcom. honours

# %%
df['Bachelors\' Degree'][0].split()
# Out:
# ['b.tech']

# %%
# for i in df['Bachelors\' Degree']:
#   i=i.split()
#   if i in ['b.tech','bachelor','b-tech','engineering']:

# %%
# for i in range(len(df['Bachelors\' Degree'])):
#   j=df['Bachelors\' Degree'][i].split()
#   if j in ['b.tech','bachelor','b-tech','engineering']:
#     df['Bachelors\' Degree'][i] = 'Bachelor'
#   else:
#     df['Bachelors\' Degree'][i] = 'Degree'

# %%
for i in range(len(df['Bachelors\' Degree'])):
    j = df['Bachelors\' Degree'][i].split()

    # Check if any keyword is present in the split list
    if any(keyword.lower() in j for keyword in ['b.tech', 'bachelor', 'b-tech', 'engineering']):
        df.at[i, 'Bachelors\' Degree'] = 'Bachelor'
    else:
        df.at[i, 'Bachelors\' Degree'] = 'Degree'

# Print the updated DataFrame

# %%
df['Bachelors\' Degree']
# Out:
# 0      Bachelor
# 1      Bachelor
# 2      Bachelor
# 3      Bachelor
# 4        Degree
#          ...
# 165      Degree
# 166      Degree
# 167      Degree
# 168      Degree
# 169    Bachelor
# Name: Bachelors' Degree, Length: 170, dtype: object

# %%
df['Bachelors\' Degree'].unique()
# Out:
# array(['Bachelor', 'Degree'], dtype=object)

# %%
df.head()
# Out:
#    Age  Gender Class X percentage/CGPA  Class XII percentage/CGPA  \
# 0   23    Male                      92                      93.00
# 1   23  Female                     9.4                      78.80
# 2   24  Female                     8.8                      86.20
# 3   24    Male                    89.4                      77.20
# 4   22  Female                9.4 cgpa                       0.89
#
#   Bachelors' Degree Bachelors' Marks/CGPA  \
# 0          Bachelor                  8.66
# 1          Bachelor              821/1000
# 2          Bachelor                   8.8
# 3          Bachelor                   7.2
# 4            Degree             7.34 cgpa
#
#    Work Experience (in completed months) (write 0 if fresher)  Term 1 CGPA  \
# 0                                                  0                  3.00
# 1                                                  0                  3.06
# 2                                                 27                  2.58
# ...

# %%
for i in range(len(df['Class X percentage/CGPA'])):
  j=str(df['Class X percentage/CGPA'][i]).split()
  df['Class X percentage/CGPA'][i] = j[0]
# Out:
# <ipython-input-992-41457b726b54>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Class X percentage/CGPA'][i] = j[0]

# %%
df['Class X percentage/CGPA'].unique()
# Out:
# array(['92', '9.4', '8.8', '89.4', '9', '88.33', '9.6', '10', '8.4/10',
#        '7.81', '9.2', '82.85', '8.4', '9.8', '83.58', '88.35', '0.89',
#        '7.8', '91.11', '71', '68', '8', '9.3', '80', '81.4', '82', '7.6',
#        '85.17', '95', '8.2', '79', '95.6', '85.2', '8.6/', '87.27',
#        '88.92', '91.2', '92.3', '77.17', '88.83', '0.844', '87.5', '89',
#        '94', '7', '0.77', '74', '0.76', '2022-10-10', '0.7617', 'CGPA',
#        '81.8', '87.4', '0.8309', '0.7067', '83.6', '6.6', '90.8', '98.8',
#        '88.5', '8?2', '8.6', '88.4', '9.5', '90.2', '0.931', '0.837',
#        '92.6', '86.4', '94.6', '9.60/10.00', '78', '0.72', '77.14', '0.9',
#        '93.64', '88', '79.4', '0.846', '90', '8.6/10', '83', '84.6',
#        '0.8233', '75', '0.78', '84.16', '7.2/10', '69.83'], dtype=object)

# %%
for i in range(len(df['Class X percentage/CGPA'])):
  j=str(df['Class X percentage/CGPA'][i]).split()
  df['Class X percentage/CGPA'][i] = j[0]
# Out:
# <ipython-input-994-41457b726b54>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Class X percentage/CGPA'][i] = j[0]

# %%
for i in range(len(df['Class X percentage/CGPA'])):
  j=str(df['Class X percentage/CGPA'][i]).split('/')
  df['Class X percentage/CGPA'][i] = j[0]
# Out:
# <ipython-input-995-1c4297c1b552>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Class X percentage/CGPA'][i] = j[0]

# %%
df['Class X percentage/CGPA'].unique()
# Out:
# array(['92', '9.4', '8.8', '89.4', '9', '88.33', '9.6', '10', '8.4',
#        '7.81', '9.2', '82.85', '9.8', '83.58', '88.35', '0.89', '7.8',
#        '91.11', '71', '68', '8', '9.3', '80', '81.4', '82', '7.6',
#        '85.17', '95', '8.2', '79', '95.6', '85.2', '8.6', '87.27',
#        '88.92', '91.2', '92.3', '77.17', '88.83', '0.844', '87.5', '89',
#        '94', '7', '0.77', '74', '0.76', '2022-10-10', '0.7617', 'CGPA',
#        '81.8', '87.4', '0.8309', '0.7067', '83.6', '6.6', '90.8', '98.8',
#        '88.5', '8?2', '88.4', '9.5', '90.2', '0.931', '0.837', '92.6',
#        '86.4', '94.6', '9.60', '78', '0.72', '77.14', '0.9', '93.64',
#        '88', '79.4', '0.846', '90', '83', '84.6', '0.8233', '75', '0.78',
#        '84.16', '7.2', '69.83'], dtype=object)

# %%
df['Class X percentage/CGPA'].unique()
df['Class X percentage/CGPA'] = df['Class X percentage/CGPA'].replace(['2022-10-10','CGPA','8?2'],[0,0,8.2])

# %%
df['Class X percentage/CGPA'].unique()
# Out:
# array(['92', '9.4', '8.8', '89.4', '9', '88.33', '9.6', '10', '8.4',
#        '7.81', '9.2', '82.85', '9.8', '83.58', '88.35', '0.89', '7.8',
#        '91.11', '71', '68', '8', '9.3', '80', '81.4', '82', '7.6',
#        '85.17', '95', '8.2', '79', '95.6', '85.2', '8.6', '87.27',
#        '88.92', '91.2', '92.3', '77.17', '88.83', '0.844', '87.5', '89',
#        '94', '7', '0.77', '74', '0.76', 0, '0.7617', '81.8', '87.4',
#        '0.8309', '0.7067', '83.6', '6.6', '90.8', '98.8', '88.5', 8.2,
#        '88.4', '9.5', '90.2', '0.931', '0.837', '92.6', '86.4', '94.6',
#        '9.60', '78', '0.72', '77.14', '0.9', '93.64', '88', '79.4',
#        '0.846', '90', '83', '84.6', '0.8233', '75', '0.78', '84.16',
#        '7.2', '69.83'], dtype=object)

# %%
len(df['Class X percentage/CGPA'][0].split('.'))
# Out:
# 1

# %%
for i in range(len(df['Class X percentage/CGPA'])):
  # if str(i).split()[0] == '0':
  if len(str(i).split()) > 1:
    df['Class X percentage/CGPA'][i] = df['Class X percentage/CGPA'][i]*9.5

# %%
df['Class X percentage/CGPA'].unique()
# Out:
# array(['92', '9.4', '8.8', '89.4', '9', '88.33', '9.6', '10', '8.4',
#        '7.81', '9.2', '82.85', '9.8', '83.58', '88.35', '0.89', '7.8',
#        '91.11', '71', '68', '8', '9.3', '80', '81.4', '82', '7.6',
#        '85.17', '95', '8.2', '79', '95.6', '85.2', '8.6', '87.27',
#        '88.92', '91.2', '92.3', '77.17', '88.83', '0.844', '87.5', '89',
#        '94', '7', '0.77', '74', '0.76', 0, '0.7617', '81.8', '87.4',
#        '0.8309', '0.7067', '83.6', '6.6', '90.8', '98.8', '88.5', 8.2,
#        '88.4', '9.5', '90.2', '0.931', '0.837', '92.6', '86.4', '94.6',
#        '9.60', '78', '0.72', '77.14', '0.9', '93.64', '88', '79.4',
#        '0.846', '90', '83', '84.6', '0.8233', '75', '0.78', '84.16',
#        '7.2', '69.83'], dtype=object)

# %%
df['Class X percentage/CGPA'] = df['Class X percentage/CGPA'].apply(lambda x: float(x))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170 entries, 0 to 169
# Data columns (total 11 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   Age                                                         170 non-null    int64
#  1   Gender                                                      170 non-null    object
#  2   Class X percentage/CGPA                                     170 non-null    float64
#  3   Class XII percentage/CGPA                                   170 non-null    float64
#  4   Bachelors' Degree                                           170 non-null    object
#  5   Bachelors' Marks/CGPA                                       170 non-null    object
#  6   Work Experience (in completed months) (write 0 if fresher)  170 non-null    int64
# ...

# %%
for i in range(len(df['Class X percentage/CGPA'])):
  if df['Class X percentage/CGPA'][i] <= 10:
    df['Class X percentage/CGPA'][i] = df['Class X percentage/CGPA'][i] * 9.5

for i in range(len(df['Class X percentage/CGPA'])):
  if df['Class X percentage/CGPA'][i] <= 1:
    df['Class X percentage/CGPA'][i] = df['Class X percentage/CGPA'][i] * 100
# Out:
# <ipython-input-1004-bca034751ce6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Class X percentage/CGPA'][i] = df['Class X percentage/CGPA'][i] * 9.5
# <ipython-input-1004-bca034751ce6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Class X percentage/CGPA'][i] = df['Class X percentage/CGPA'][i] * 100

# %%
df['Class X percentage/CGPA'].unique()
# Out:
# array([92.     , 89.3    , 83.6    , 89.4    , 85.5    , 88.33   ,
#        91.2    , 95.     , 79.8    , 74.195  , 87.4    , 82.85   ,
#        93.1    , 83.58   , 88.35   ,  8.455  , 74.1    , 91.11   ,
#        71.     , 68.     , 76.     , 88.35   , 80.     , 81.4    ,
#        82.     , 72.2    , 85.17   , 77.9    , 79.     , 95.6    ,
#        85.2    , 81.7    , 87.27   , 88.92   , 92.3    , 77.17   ,
#        88.83   ,  8.018  , 87.5    , 89.     , 94.     , 66.5    ,
#         7.315  , 74.     ,  7.22   ,  0.     ,  7.23615, 81.8    ,
#        87.4    ,  7.89355,  6.71365, 83.6    , 62.7    , 90.8    ,
#        98.8    , 88.5    , 88.4    , 90.25   , 90.2    ,  8.8445 ,
#         7.9515 , 92.6    , 86.4    , 94.6    , 78.     ,  6.84   ,
#        77.14   ,  8.55   , 93.64   , 88.     , 79.4    ,  8.037  ,
#        90.     , 83.     , 84.6    ,  7.82135, 75.     ,  7.41   ,
#        84.16   , 68.4    , 69.83   ])

# %%
df['Class X percentage/CGPA'] = df['Class X percentage/CGPA'].replace(0,df['Class X percentage/CGPA'].mean())
df['Class X percentage/CGPA'] = df['Class X percentage/CGPA'].round(2)

# %%
df.head()
# Out:
#    Age  Gender  Class X percentage/CGPA  Class XII percentage/CGPA  \
# 0   23    Male                     92.0                      93.00
# 1   23  Female                     89.3                      78.80
# 2   24  Female                     83.6                      86.20
# 3   24    Male                     89.4                      77.20
# 4   22  Female                     89.3                       0.89
#
#   Bachelors' Degree Bachelors' Marks/CGPA  \
# 0          Bachelor                  8.66
# 1          Bachelor              821/1000
# 2          Bachelor                   8.8
# 3          Bachelor                   7.2
# 4            Degree             7.34 cgpa
#
#    Work Experience (in completed months) (write 0 if fresher)  Term 1 CGPA  \
# 0                                                  0                  3.00
# 1                                                  0                  3.06
# 2                                                 27                  2.58
# ...

# %%
df['Class XII percentage/CGPA'].unique()
# Out:
# array([93.    , 78.8   , 86.2   , 77.2   ,  0.89  , 67.4   , 80.2   ,
#        76.15  , 94.    , 72.    ,  0.85  ,  0.805 , 65.2   ,  0.65  ,
#        95.6   , 78.    , 85.83  , 80.    , 69.85  ,  0.9   ,  0.712 ,
#        92.75  , 76.4   , 66.    , 67.    , 70.    ,  0.8   ,  0.91  ,
#         0.984 , 82.    , 89.8   , 71.    , 89.2   , 88.    , 92.8   ,
#         7.09  , 86.    ,  0.94  , 84.25  , 78.2   , 88.33  , 79.83  ,
#        74.8   , 81.4   , 63.2   ,  0.88  , 93.4   , 84.47  , 85.4   ,
#        96.1   , 82.14  , 71.2   , 79.8   , 77.07  , 77.5   ,  0.78  ,
#        82.2   , 76.8   , 87.    , 95.    ,  0.926 ,  0.79  ,  0.858 ,
#        85.    ,  9.    ,  0.72  , 75.    , 93.2   ,  0.82  , 79.    ,
#         0.7317, 76.3   ,  0.95  , 94.2   , 88.67  , 91.4   ,  0.7369,
#        95.4   , 85.2   , 87.4   ,  0.852 , 74.25  ,  0.847 , 91.    ,
#        72.6   ,  0.866 , 74.16  ,  0.7467, 78.4   , 95.67  ,  7.4   ,
# ...

# %%
df['Class XII percentage/CGPA'].unique()
# Out:
# array([93.    , 78.8   , 86.2   , 77.2   ,  0.89  , 67.4   , 80.2   ,
#        76.15  , 94.    , 72.    ,  0.85  ,  0.805 , 65.2   ,  0.65  ,
#        95.6   , 78.    , 85.83  , 80.    , 69.85  ,  0.9   ,  0.712 ,
#        92.75  , 76.4   , 66.    , 67.    , 70.    ,  0.8   ,  0.91  ,
#         0.984 , 82.    , 89.8   , 71.    , 89.2   , 88.    , 92.8   ,
#         7.09  , 86.    ,  0.94  , 84.25  , 78.2   , 88.33  , 79.83  ,
#        74.8   , 81.4   , 63.2   ,  0.88  , 93.4   , 84.47  , 85.4   ,
#        96.1   , 82.14  , 71.2   , 79.8   , 77.07  , 77.5   ,  0.78  ,
#        82.2   , 76.8   , 87.    , 95.    ,  0.926 ,  0.79  ,  0.858 ,
#        85.    ,  9.    ,  0.72  , 75.    , 93.2   ,  0.82  , 79.    ,
#         0.7317, 76.3   ,  0.95  , 94.2   , 88.67  , 91.4   ,  0.7369,
#        95.4   , 85.2   , 87.4   ,  0.852 , 74.25  ,  0.847 , 91.    ,
#        72.6   ,  0.866 , 74.16  ,  0.7467, 78.4   , 95.67  ,  7.4   ,
# ...

# %%
for i in range(len(df['Class XII percentage/CGPA'])):
  if df['Class XII percentage/CGPA'][i] <= 10:
    df['Class XII percentage/CGPA'][i] = df['Class XII percentage/CGPA'][i] * 9.5
# Out:
# <ipython-input-1010-8d81bb9a6b98>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Class XII percentage/CGPA'][i] = df['Class XII percentage/CGPA'][i] * 9.5

# %%
df['Class XII percentage/CGPA'] = df['Class XII percentage/CGPA'].round(2)

# %%
for i in range(len(df['Class XII percentage/CGPA'])):
  if df['Class XII percentage/CGPA'][i] <= 10:
    df['Class XII percentage/CGPA'][i] = df['Class XII percentage/CGPA'][i] * 9.5
# Out:
# <ipython-input-1012-8d81bb9a6b98>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Class XII percentage/CGPA'][i] = df['Class XII percentage/CGPA'][i] * 9.5

# %%
df['Class XII percentage/CGPA'] = df['Class XII percentage/CGPA'].round(2)

# %%
df['Class XII percentage/CGPA'].unique()
# Out:
# array([93.  , 78.8 , 86.2 , 77.2 , 80.37, 67.4 , 80.2 , 76.15, 94.  ,
#        72.  , 76.67, 72.68, 65.2 , 58.71, 95.6 , 78.  , 85.83, 80.  ,
#        69.85, 81.23, 64.22, 92.75, 76.4 , 66.  , 67.  , 70.  , 72.2 ,
#        82.08, 88.82, 82.  , 89.8 , 71.  , 89.2 , 88.  , 92.8 , 67.36,
#        86.  , 84.84, 84.25, 78.2 , 88.33, 79.83, 74.8 , 81.4 , 63.2 ,
#        79.42, 93.4 , 84.47, 85.4 , 96.1 , 82.14, 71.2 , 79.8 , 77.07,
#        77.5 , 70.4 , 82.2 , 76.8 , 87.  , 95.  , 83.6 , 71.34, 77.42,
#        85.  , 85.5 , 64.98, 75.  , 93.2 , 74.  , 79.  , 66.03, 76.3 ,
#        85.69, 94.2 , 88.67, 91.4 , 66.5 , 95.4 , 85.2 , 87.4 , 76.86,
#        74.25, 76.48, 91.  , 72.6 , 78.18, 74.16, 78.4 , 95.67, 70.3 ,
#        80.4 , 84.5 , 96.  , 71.16, 79.61, 76.5 , 75.62, 92.2 , 92.  ,
#        87.86, 74.19, 72.77, 89.25, 83.41, 92.4 , 70.6 , 71.44, 68.59,
#        75.5 , 85.31, 84.  , 76.77, 78.25, 90.2 , 73.62, 92.7 , 83.12,
#        85.25, 71.33, 90.6 , 90.  , 70.2 , 72.67, 68.4 ])

# %%
df.head()
# Out:
#    Age  Gender  Class X percentage/CGPA  Class XII percentage/CGPA  \
# 0   23    Male                     92.0                      93.00
# 1   23  Female                     89.3                      78.80
# 2   24  Female                     83.6                      86.20
# 3   24    Male                     89.4                      77.20
# 4   22  Female                     89.3                      80.37
#
#   Bachelors' Degree Bachelors' Marks/CGPA  \
# 0          Bachelor                  8.66
# 1          Bachelor              821/1000
# 2          Bachelor                   8.8
# 3          Bachelor                   7.2
# 4            Degree             7.34 cgpa
#
#    Work Experience (in completed months) (write 0 if fresher)  Term 1 CGPA  \
# 0                                                  0                  3.00
# 1                                                  0                  3.06
# 2                                                 27                  2.58
# ...

# %%
df['Bachelors\' Marks/CGPA'].unique()
# Out:
# array([8.66, '821/1000', 8.8, 7.2, '7.34 cgpa', 7.53, 8.75, '8.86 cgpa',
#        65, '8.541/10', 7.51, 0.67, 0.8144, 54.61, '7.27 CGPA', 7.83, 7.7,
#        '9.15/10', 8.53, 7.14, 61.2, '9.25 / 10', 0.745, 0.72, 7.05, 6.9,
#        '8.4/10', 84, 0.68, '7.851 CGPA', '7.18 CGPA', 7.3, 0.747, 81,
#        '7.58 CGPA', 69.9, '6.67/10', 8.314, 74.8, 8.05, 8.64, 0.799, 84.6,
#        8.13, 0.861, 70.11, 7.54, 85.9, 6.67, 6.8, 68, '6.55/ 10.00',
#        '9.57/10', 8.31, 7.34, 72.1, 8.61, 7.89, 65.05, 7.41, 8.04,
#        '5.71/7', 74.4, '8.162 cgpa', 80.42, 9.18, 0.758, 7.21, 9.35, 7,
#        63.45, 89, 8.1, 0.75, '7.5/10', '9.46 CGPA', 73.5, 'CGPA 7.9',
#        7.33, 6.146, '9.37/10', 0.7125, '9.2/10', 64.33, 6.74, 0.682, 88.5,
#        0.764, '9.2 CGPA', 6.7, 7.02, 0.6372, 72.69, 7.36, 6.5, 8.84, 61.5,
#        7.76, 7.18, 6.4, 6.43, 73, 9.37, 68.2, 6.581, 84.19, 7.01, 8.69,
#        7.94, 6.82, 0.69, 7.1, 8.11, 0.74, 7.635, 69, 0.92, 0.65, 65.67,
# ...

# %%
for i in range(len(df['Bachelors\' Marks/CGPA'])):
  j=str(df['Bachelors\' Marks/CGPA'][i]).split()
  df['Bachelors\' Marks/CGPA'][i] = j[0]
# Out:
# <ipython-input-1017-aaa13638cb9b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Bachelors\' Marks/CGPA'][i] = j[0]

# %%
for i in range(len(df['Bachelors\' Marks/CGPA'])):
  j=str(df['Bachelors\' Marks/CGPA'][i]).split('/')
  df['Bachelors\' Marks/CGPA'][i] = j[0]
# Out:
# <ipython-input-1018-10564438afc8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Bachelors\' Marks/CGPA'][i] = j[0]

# %%
df['Bachelors\' Marks/CGPA'].unique()
# Out:
# array(['8.66', '821', '8.8', '7.2', '7.34', '7.53', '8.75', '8.86', '65',
#        '8.541', '7.51', '0.67', '0.8144', '54.61', '7.27', '7.83', '7.7',
#        '9.15', '8.53', '7.14', '61.2', '9.25', '0.745', '0.72', '7.05',
#        '6.9', '8.4', '84', '0.68', '7.851', '7.18', '7.3', '0.747', '81',
#        '7.58', '69.9', '6.67', '8.314', '74.8', '8.05', '8.64', '0.799',
#        '84.6', '8.13', '0.861', '70.11', '7.54', '85.9', '6.8', '68',
#        '6.55', '9.57', '8.31', '72.1', '8.61', '7.89', '65.05', '7.41',
#        '8.04', '5.71', '74.4', '8.162', '80.42', '9.18', '0.758', '7.21',
#        '9.35', '7', '63.45', '89', '8.1', '0.75', '7.5', '9.46', '73.5',
#        'CGPA', '7.33', '6.146', '9.37', '0.7125', '9.2', '64.33', '6.74',
#        '0.682', '88.5', '0.764', '6.7', '7.02', '0.6372', '72.69', '7.36',
#        '6.5', '8.84', '61.5', '7.76', '6.4', '6.43', '73', '68.2',
#        '6.581', '84.19', '7.01', '8.69', '7.94', '6.82', '0.69', '7.1',
# ...

# %%
df['Bachelors\' Marks/CGPA'] = df['Bachelors\' Marks/CGPA'].replace('CGPA',0)

# %%
df['Bachelors\' Marks/CGPA'].unique()
# Out:
# array(['8.66', '821', '8.8', '7.2', '7.34', '7.53', '8.75', '8.86', '65',
#        '8.541', '7.51', '0.67', '0.8144', '54.61', '7.27', '7.83', '7.7',
#        '9.15', '8.53', '7.14', '61.2', '9.25', '0.745', '0.72', '7.05',
#        '6.9', '8.4', '84', '0.68', '7.851', '7.18', '7.3', '0.747', '81',
#        '7.58', '69.9', '6.67', '8.314', '74.8', '8.05', '8.64', '0.799',
#        '84.6', '8.13', '0.861', '70.11', '7.54', '85.9', '6.8', '68',
#        '6.55', '9.57', '8.31', '72.1', '8.61', '7.89', '65.05', '7.41',
#        '8.04', '5.71', '74.4', '8.162', '80.42', '9.18', '0.758', '7.21',
#        '9.35', '7', '63.45', '89', '8.1', '0.75', '7.5', '9.46', '73.5',
#        0, '7.33', '6.146', '9.37', '0.7125', '9.2', '64.33', '6.74',
#        '0.682', '88.5', '0.764', '6.7', '7.02', '0.6372', '72.69', '7.36',
#        '6.5', '8.84', '61.5', '7.76', '6.4', '6.43', '73', '68.2',
#        '6.581', '84.19', '7.01', '8.69', '7.94', '6.82', '0.69', '7.1',
# ...

# %%
df['Bachelors\' Marks/CGPA'] = df['Bachelors\' Marks/CGPA'].astype(float)

# %%
for i in range(len(df['Bachelors\' Marks/CGPA'])):
  if df['Bachelors\' Marks/CGPA'][i] <= 10:
    df['Bachelors\' Marks/CGPA'][i] = df['Bachelors\' Marks/CGPA'][i] * 9.5

for i in range(len(df['Bachelors\' Marks/CGPA'])):
  if df['Bachelors\' Marks/CGPA'][i] <= 1:
    df['Bachelors\' Marks/CGPA'][i] = df['Bachelors\' Marks/CGPA'][i] * 100
# Out:
# <ipython-input-1023-3cb2fb88df29>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Bachelors\' Marks/CGPA'][i] = df['Bachelors\' Marks/CGPA'][i] * 9.5
# <ipython-input-1023-3cb2fb88df29>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Bachelors\' Marks/CGPA'][i] = df['Bachelors\' Marks/CGPA'][i] * 100

# %%
for i in range(len(df['Bachelors\' Marks/CGPA'])):
  if df['Bachelors\' Marks/CGPA'][i] <= 10:
    df['Bachelors\' Marks/CGPA'][i] = df['Bachelors\' Marks/CGPA'][i] * 9.5
# Out:
# <ipython-input-1024-34c0effd8199>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Bachelors\' Marks/CGPA'][i] = df['Bachelors\' Marks/CGPA'][i] * 9.5

# %%
df['Bachelors\' Marks/CGPA'] = df['Bachelors\' Marks/CGPA'].replace(0,df['Bachelors\' Marks/CGPA'].mean())
df['Bachelors\' Marks/CGPA'] = df['Bachelors\' Marks/CGPA'].round(2)

# %%
df['Bachelors\' Marks/CGPA'].unique()
# Out:
# array([ 82.27, 821.  ,  83.6 ,  68.4 ,  69.73,  71.54,  83.12,  84.17,
#         65.  ,  81.14,  71.34,  60.47,  73.5 ,  54.61,  69.06,  74.39,
#         73.15,  86.92,  81.04,  67.83,  61.2 ,  87.88,  67.24,  64.98,
#         66.97,  65.55,  79.8 ,  84.  ,  61.37,  74.58,  68.21,  69.35,
#         67.42,  81.  ,  72.01,  69.9 ,  63.36,  78.98,  74.8 ,  76.48,
#         82.08,  72.11,  84.6 ,  77.24,  77.71,  70.11,  71.63,  85.9 ,
#         64.6 ,  68.  ,  62.22,  90.92,  78.95,  72.1 ,  81.79,  74.96,
#         65.05,  70.4 ,  76.38,  54.24,  74.4 ,  77.54,  80.42,  87.21,
#         68.41,  68.5 ,  88.82,  66.5 ,  63.45,  89.  ,  76.95,  67.69,
#         71.25,  89.87,  75.62,  69.64,  58.39,  89.01,  64.3 ,  87.4 ,
#         64.33,  64.03,  61.55,  88.5 ,  68.95,  63.65,  66.69,  57.51,
#         72.69,  69.92,  61.75,  83.98,  61.5 ,  73.72,  60.8 ,  61.08,
#         73.  ,  68.2 ,  62.52,  84.19,  66.6 ,  82.56,  75.43,  64.79,
# ...

# %%
df.head()
# Out:
#    Age  Gender  Class X percentage/CGPA  Class XII percentage/CGPA  \
# 0   23    Male                     92.0                      93.00
# 1   23  Female                     89.3                      78.80
# 2   24  Female                     83.6                      86.20
# 3   24    Male                     89.4                      77.20
# 4   22  Female                     89.3                      80.37
#
#   Bachelors' Degree  Bachelors' Marks/CGPA  \
# 0          Bachelor                  82.27
# 1          Bachelor                 821.00
# 2          Bachelor                  83.60
# 3          Bachelor                  68.40
# 4            Degree                  69.73
#
#    Work Experience (in completed months) (write 0 if fresher)  Term 1 CGPA  \
# 0                                                  0                  3.00
# 1                                                  0                  3.06
# ...

# %%
df['Work Experience (in completed months) (write 0 if fresher)'].unique()
# Out:
# array([ 0, 27,  5, 23, 11, 18, 24,  9, 10, 14, 15, 12, 19,  3, 22,  6,  2,
#         8, 17,  7, 16, 13])

# %%
df['Term 1 CGPA'].unique()
# Out:
# array([3.  , 3.06, 2.58, 2.7 , 2.92, 2.55, 3.2 , 3.56, 2.89, 3.42, 3.38,
#        3.1 , 3.14, 2.35, 3.29, 3.24, 3.59, 2.8 , 3.02, 3.64, 2.75, 2.94,
#        2.76, 3.15, 3.33, 3.23, 3.19, 3.04, 2.78, 3.61, 3.01, 2.86, 3.5 ,
#        3.3 , 3.09, 3.21, 2.77, 2.91, 3.26, 3.54, 2.97, 2.96, 3.03, 2.98,
#        3.11, 3.52, 3.13, 3.67, 3.35, 2.82, 2.83, 3.36, 3.53, 3.27, 3.49,
#        2.88, 3.18, 3.12, 3.4 , 2.67, 3.32, 2.9 , 3.77, 3.44, 3.47, 2.44,
#        2.62, 3.41, 2.1 , 2.85, 2.21, 2.99, 2.95, 2.79, 3.39, 2.68])

# %%
df['Salary'].unique()
# Out:
# array([14, 12, 17,  8, 18, 15, 10, 16, 11, 13, 19,  9])

# %%
df['Attempts'].unique()
# Out:
# array([4, 7, 3, 5, 1, 9, 2, 8, 6])

# %%
df['Placed by week'].unique()
# Out:
# array([2, 3, 1, 'Others'], dtype=object)

# %%
df['Placed by week'] = df['Placed by week'].replace(['Others'],df['Placed by week'].mode()[0])

# %%
# df.to_csv('cleaned_data.csv', index=False)
print(len(column_list))
# Out:
# 10

# %%
df["Bachelors' Marks/CGPA"] = df["Bachelors' Marks/CGPA"].replace(821,82)

# %%
plt.figure(figsize=(20, 10))
column_list = df.columns
column_list = column_list.drop(['Bachelors\' Degree', 'Gender'])
lent = column_list.shape[0]

for i in range(lent):
    plt.subplot(5, 2, i+1)
    sns.boxplot(y=df[column_list[i]])
    plt.title('Boxplot of {}'.format(column_list[i]))

plt.tight_layout()
plt.show()

# %%
len(column_list)
# Out:
# 9

# %%
def detect_outlier(col):
    q1,q3 = np.percentile(col,[25,75])
    iqr = q3 - q1
    up_lim = q3 + (1.5 * iqr)
    lr_lim = q1 - (1.5 * iqr)
    return lr_lim,up_lim

# %%
column_list = df.columns.drop(['Bachelors\' Degree', 'Gender'])
for i in column_list:
    lr,ur = detect_outlier(df[i])
    df[i] = np.where(df[i]>ur,ur,df[i])
    df[i] = np.where(df[i]<lr,lr,df[i])

# %%
plt.figure(figsize=(15,20))
column_list = df.columns.drop(['Bachelors\' Degree', 'Gender'])
lent=column_list.shape[0]
for i in range(lent):
    plt.subplot(7,2,i+1)
    sns.boxplot(y=df[column_list[i]],data=df)
    plt.title('Boxplot of {}'.format(column_list[i]))
    plt.tight_layout()

# %%
df['Placed by week'].unique()
# Out:
# array([2., 3., 1.])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170 entries, 0 to 169
# Data columns (total 11 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   Age                                                         170 non-null    float64
#  1   Gender                                                      170 non-null    object
#  2   Class X percentage/CGPA                                     170 non-null    float64
#  3   Class XII percentage/CGPA                                   170 non-null    float64
#  4   Bachelors' Degree                                           170 non-null    object
#  5   Bachelors' Marks/CGPA                                       170 non-null    float64
#  6   Work Experience (in completed months) (write 0 if fresher)  170 non-null    float64
# ...

# %%
df.head()
# Out:
#     Age  Gender  Class X percentage/CGPA  Class XII percentage/CGPA  \
# 0  23.0    Male                     92.0                      93.00
# 1  23.0  Female                     89.3                      78.80
# 2  24.0  Female                     83.6                      86.20
# 3  24.0    Male                     89.4                      77.20
# 4  22.0  Female                     89.3                      80.37
#
#   Bachelors' Degree  Bachelors' Marks/CGPA  \
# 0          Bachelor                  82.27
# 1          Bachelor                  82.00
# 2          Bachelor                  83.60
# 3          Bachelor                  68.40
# 4            Degree                  69.73
#
#    Work Experience (in completed months) (write 0 if fresher)  Term 1 CGPA  \
# 0                                              0.000                  3.00
# 1                                              0.000                  3.06
# ...

# %% [markdown]
# Encode

# %%
from sklearn.preprocessing import OneHotEncoder
categorical_columns = df.select_dtypes(include=['object']).columns

df_categorical = df[categorical_columns]

encoder = OneHotEncoder(sparse=False, drop='first')
# Fit and transform the categorical columns
df_encoded = pd.DataFrame(encoder.fit_transform(df_categorical), columns=encoder.get_feature_names_out(df_categorical.columns))

# Concatenate the encoded DataFrame with the original DataFrame
df = pd.concat([df, df_encoded], axis=1)

# Drop the original categorical columns
df = df.drop(categorical_columns, axis=1)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
df.head()
# Out:
#     Age  Class X percentage/CGPA  Class XII percentage/CGPA  \
# 0  23.0                     92.0                      93.00
# 1  23.0                     89.3                      78.80
# 2  24.0                     83.6                      86.20
# 3  24.0                     89.4                      77.20
# 4  22.0                     89.3                      80.37
#
#    Bachelors' Marks/CGPA  \
# 0                  82.27
# 1                  82.00
# 2                  83.60
# 3                  68.40
# 4                  69.73
#
#    Work Experience (in completed months) (write 0 if fresher)  Term 1 CGPA  \
# 0                                              0.000                  3.00
# 1                                              0.000                  3.06
# 2                                              6.875                  2.58
# 3                                              5.000                  2.70
# ...

# %% [markdown]
# Perform z-score scaling and discuss how it affects the speed of the algorithm.

# %%
from scipy.stats import zscore

df_scaled =  df.apply(zscore)
df_scaled.head()
# Out:
#         Age  Class X percentage/CGPA  Class XII percentage/CGPA  \
# 0  0.121212                 0.896801                   1.551636
# 1  0.121212                 0.656011                  -0.136209
# 2  0.979798                 0.147677                   0.743372
# 3  0.979798                 0.664929                  -0.326389
# 4 -0.737374                 0.656011                   0.050405
#
#    Bachelors' Marks/CGPA  \
# 0               1.211962
# 1               1.180963
# 2               1.364661
# 3              -0.380471
# 4              -0.227772
#
#    Work Experience (in completed months) (write 0 if fresher)  Term 1 CGPA  \
# 0                                          -0.595452             -0.346702
# 1                                          -0.595452             -0.131726
# 2                                           1.791974             -1.851539
# 3                                           1.140858             -1.421585
# ...

# %% [markdown]
# All such distance based algorithms are affected by the scale of the variables.
#
# The most common way is to calculate the Euclidean distance
#
# We do not want our algorithm to be affected by the magnitude of these variables. The algorithm should not be biased towards variables with higher magnitude.
#
# To overcome this problem, we can bring down all the variables to the same scale.
#
# If we could see the data which is not scaled, the data is of different scales. The scale of Ad-length is in hundreds, Ad-size is in Thousands, and some other columns are with very less scale.
#
# This effects the Euclidean distance.

# %%
import scipy.cluster.hierarchy as hrchy

# %%
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster

# %% [markdown]
# WARD

# %%
wardlink = linkage(df_scaled, method = 'ward')

# %%
plt.figure(figsize=(20,7))
dend = dendrogram(wardlink,
                 truncate_mode='lastp',
                 p = 10,
                 )

# %%
plt.figure(figsize=(20,7))
dend = dendrogram(wardlink,
                 truncate_mode='lastp',
                 p = 5,
                 )

# %%
plt.figure(figsize=(20,7))
dend = dendrogram(wardlink,
                 truncate_mode='lastp',
                 p = 4,
                 )

# %%
clusters = fcluster(wardlink, 5, criterion='maxclust')
clusters
# Out:
# array([4, 1, 5, 3, 1, 3, 1, 4, 5, 1, 4, 1, 1, 3, 3, 5, 3, 1, 4, 2, 3, 5,
#        2, 1, 2, 3, 2, 1, 2, 1, 3, 4, 1, 5, 1, 5, 2, 1, 5, 2, 1, 1, 5, 4,
#        5, 2, 3, 1, 1, 2, 1, 2, 5, 3, 5, 4, 5, 5, 3, 3, 2, 2, 3, 4, 1, 2,
#        4, 5, 1, 2, 1, 5, 4, 1, 2, 4, 5, 2, 2, 1, 2, 5, 1, 1, 1, 1, 1, 2,
#        5, 1, 3, 2, 5, 2, 5, 1, 5, 3, 2, 1, 1, 2, 5, 4, 4, 2, 5, 3, 2, 5,
#        2, 4, 2, 5, 2, 2, 5, 1, 4, 2, 3, 2, 3, 4, 1, 1, 4, 1, 1, 3, 3, 5,
#        2, 3, 2, 1, 3, 3, 5, 2, 4, 4, 4, 4, 1, 2, 1, 2, 5, 3, 5, 5, 5, 2,
#        1, 1, 4, 2, 5, 2, 4, 5, 2, 2, 5, 1, 5, 2, 5, 3], dtype=int32)

# %%
clus_df = df.copy()

# %%
clus_df['Cluster'] = clusters

# %%
clus_df.groupby(by='Cluster').mean()
# Out:
#                Age  Class X percentage/CGPA  Class XII percentage/CGPA  \
# Cluster
# 1        22.279070                85.976279                  81.549535
# 2        22.476190                71.861905                  73.998333
# 3        24.280000                82.278400                  75.501200
# 4        23.130435                87.712174                  81.634783
# 5        22.837838                84.891216                  86.787027
#
#          Bachelors' Marks/CGPA  \
# Cluster
# 1                    73.803953
# 2                    66.917619
# 3                    66.847600
# 4                    75.587826
# 5                    75.609189
#
#          Work Experience (in completed months) (write 0 if fresher)  \
# Cluster
# 1                                                 1.029070
# 2                                                 0.470238
# 3                                                 5.670000
# 4                                                 0.260870
# ...

# %%
clus_df['Cluster'].value_counts().sort_index()
# Out:
# 1    43
# 2    42
# 3    25
# 4    23
# 5    37
# Name: Cluster, dtype: int64

# %%
df_clust = clus_df.groupby('Cluster').mean()
cluster_freq = clus_df['Cluster'].value_counts().sort_index()
df_clust['cluster count'] = cluster_freq
df_clust
# Out:
#                Age  Class X percentage/CGPA  Class XII percentage/CGPA  \
# Cluster
# 1        22.279070                85.976279                  81.549535
# 2        22.476190                71.861905                  73.998333
# 3        24.280000                82.278400                  75.501200
# 4        23.130435                87.712174                  81.634783
# 5        22.837838                84.891216                  86.787027
#
#          Bachelors' Marks/CGPA  \
# Cluster
# 1                    73.803953
# 2                    66.917619
# 3                    66.847600
# 4                    75.587826
# 5                    75.609189
#
#          Work Experience (in completed months) (write 0 if fresher)  \
# Cluster
# 1                                                 1.029070
# 2                                                 0.470238
# 3                                                 5.670000
# 4                                                 0.260870
# ...

# %% [markdown]
# ELBOW CURVE

# %%
from sklearn.cluster import KMeans

# %%
wcss = []
for i in range(2, 11):
    kmeans = KMeans(n_clusters = i, random_state = 42)
    kmeans.fit(df_scaled)
    wcss.append(kmeans.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %% [markdown]
# kmeans inertia gives the within sum of squares
#
# Inertia measures how well a dataset was clustered by K-Means. It is calculated by measuring the distance between each data point and its centroid, squaring this distance, and summing these squares across one cluster.

# %%
for i in range(2,11):
    print('The WSS value for',i,'clusters is',wcss[i-2])
# Out:
# The WSS value for 2 clusters is 1420.0524221584133
# The WSS value for 3 clusters is 1261.0920131253583
# The WSS value for 4 clusters is 1141.674894080611
# The WSS value for 5 clusters is 1079.0399870441138
# The WSS value for 6 clusters is 1026.6569919042925
# The WSS value for 7 clusters is 970.26131913206
# The WSS value for 8 clusters is 929.844410113179
# The WSS value for 9 clusters is 880.8957439075706
# The WSS value for 10 clusters is 844.2330054494555

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(x=range(2, 11), y=wcss, marker='o', color='red')
plt.title('The Elbow Plot')
plt.xlabel('Number of clusters')
plt.ylabel('WSS')
plt.show()

# %%
from sklearn.metrics import silhouette_samples, silhouette_score

# %%
silscores=[]
for i in range(2,11):
    kmeans = KMeans(n_clusters = i, random_state = 42)
    kmeans.fit(df)
    labels = kmeans.labels_
    sil_score = silhouette_score(df,labels)
    silscores.append(sil_score)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
silscores
# Out:
# [0.35102819664178336,
#  0.2434109625044337,
#  0.24301323108663236,
#  0.23434977515778993,
#  0.25788525109491567,
#  0.24460889593134216,
#  0.23973500954758703,
#  0.241781293952499,
#  0.23988793394480473]

# %% [markdown]
# ###  Profile the ads based on optimum number of clusters using silhouette score and your domain understanding

# %%
k_means = KMeans(n_clusters = 5)
k_means.fit(df)
labels = k_means.labels_
clus_df['KMeans'] = labels
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
clus_df.head()
# Out:
#     Age  Class X percentage/CGPA  Class XII percentage/CGPA  \
# 0  23.0                     92.0                      93.00
# 1  23.0                     89.3                      78.80
# 2  24.0                     83.6                      86.20
# 3  24.0                     89.4                      77.20
# 4  22.0                     89.3                      80.37
#
#    Bachelors' Marks/CGPA  \
# 0                  82.27
# 1                  82.00
# 2                  83.60
# 3                  68.40
# 4                  69.73
#
#    Work Experience (in completed months) (write 0 if fresher)  Term 1 CGPA  \
# 0                                              0.000                  3.00
# 1                                              0.000                  3.06
# 2                                              6.875                  2.58
# 3                                              5.000                  2.70
# ...

# %%
kmeans_df = clus_df.groupby('Cluster').mean()
kmeans_df['Cluster_count'] = clus_df['Cluster'].value_counts().sort_index()

# %%
kmeans_df.head()
# Out:
#                Age  Class X percentage/CGPA  Class XII percentage/CGPA  \
# Cluster
# 1        22.279070                85.976279                  81.549535
# 2        22.476190                71.861905                  73.998333
# 3        24.280000                82.278400                  75.501200
# 4        23.130435                87.712174                  81.634783
# 5        22.837838                84.891216                  86.787027
#
#          Bachelors' Marks/CGPA  \
# Cluster
# 1                    73.803953
# 2                    66.917619
# 3                    66.847600
# 4                    75.587826
# 5                    75.609189
#
#          Work Experience (in completed months) (write 0 if fresher)  \
# Cluster
# 1                                                 1.029070
# 2                                                 0.470238
# 3                                                 5.670000
# 4                                                 0.260870
# ...

# %%
sns.barplot(x=clus_df['Cluster'],y=clus_df['Placed by week'],hue=clus_df['Attempts'])
plt.title('Cluster vs --')
# Out:
# Text(0.5, 1.0, 'Cluster vs --')

# %%
sns.barplot(x=clus_df['Cluster'],y=clus_df['Age'])
plt.title('Cluster vs Age')
# Out:
# Text(0.5, 1.0, 'Cluster vs Age')

# %%
sns.barplot(x=clus_df['Cluster'],y=clus_df['Salary'])
plt.title('Cluster vs Salary ')
# Out:
# Text(0.5, 1.0, 'Cluster vs Salary ')
